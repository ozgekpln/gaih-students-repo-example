# %%
asalSayılar=[]
asalSayılar1=[]
def prime_first(sayi):
  for sayi in range(0,501):
    if sayi>1:
      for j in range(2,sayi):
        if(sayi%j)==0:
          break
      else:
        asalSayılar.append(sayi)
  print("0-500 arasındaki asal sayılar:",asalSayılar)
def prime_second(sayi):
  for sayi in range(500,1001):
    for i in range(2,sayi):
      if(sayi%i)==0:
        break
    else:
      asalSayılar1.append(sayi)
  print("500-1000 arasındaki asal sayılar:",asalSayılar1)

prime_first(sayi)
prime_second(sayi)
